# %%
#####################################################################################
# youtube_script.py
#
# Script for scraping a comments on a YouTube video using...
# Homepage URL: https://www.youtube.com/
# Tools: Selenium, Chrome Driver
# Data Organizer: Pandas
#
# Version: 2.3
# Date Created: 02/05/2019
# Last Modified: 09/09/2019
#####################################################################################

#####################################################################################
#
# V2.2 Notes:
#
# 1. Added functions to handle and get styled usernames.
#    This function is called if no username is detected for a post after
#    first trying to use the original function to get normal usernames.
# 2. Added function to make custom comment IDs called "My Comment ID" in output.
# 3. Added function to make list of URLs for output
#    where len(URLs) = len(comments) and all items are the same video URL.
# 4. Added function to get video's title from top of page below the video player.
# 5. Added function to make list of video titles for output
#    where len(video_titles) = len(comments) and all items are the same video title.
# 6. Changed global variable v_code to automatically get code from URL:
#    v_code = myURL.split("v=")[1]
#
#####################################################################################

#####################################################################################
#
# V2-3 Notes:
#
# 1. The function get_viewXreplies_elements() from previous versions is depecrated,
#    as the CSS selector for "View [x] replies" buttons is no longer "#more-text".
#    The CSS selector is now simply "#text", which is shared with many other elements
#    on the page. To filter out which elements actually correspond to "View [x] replies",
#    the RegEx "(View).*(repl).*" is used to match against each found element.text.
#    Elements whose text field matches the RegEx are then added to the actual list of
#    "View [x] replies" elements.
# 2. Changed function get_ShowMoreReplies_elements() to check if found elements' text
#    field is equal to "Show more replies". If it does match, the element is then
#    added to the actual list of "Show more replies" elements. This modification is
#    similar to the one mentioned above, except without the use of a RegEx pattern.
# 3. Added funtion to make list of sources for output
#    where len(sources) = len(comments) and all items are the same source, "YouTube".
# 4. Changed output column names to be all lowercase and without whitespace, as follows:
#    - "My Comment ID" -> "my_comment_id"
#    - "source"
#    - "Video Title" -> "video_title"
#    - "Username" -> "username"
#    - "Comment" -> "comment"
#    - "Timestamp" -> "timestamp"
#    - "Timestamp Number" -> "timestamp_number"
#    - "Timestamp Unit" -> "timestamp_unit"
#    - "Edited" -> "edited"
#    - "Upvotes" -> "upvotes"
#    - "URL" -> "url"
#
#####################################################################################

# %%
##### READ ME #######################################################################
#
# This script is able to scrape YouTube video comments on:
# https://www.youtube.com/
#
# This script's code should only be executed at portions at a time due to
# Chrome Driver being unable to open the given webpage all the time.
# Please do not run this script as an executable / as a whole.
#
##### WARNINGS ######################################################################
#
# 1. This script is prone to errors when scraping videos with 2,000+ comments.
#    Videos with 1,500+ comments are iffy...
#    This is because the browser has trouble displaying many comments at once on
#    one page, so if the browser crashes or the page becomes unresponsive,
#    the script will no longer work.
# 2. Please do not scroll or click anywhere on the browser window where Chrome Driver
#    is operating while the script is trying to click buttons or extract data.
#
##### READ ME (continued) ###########################################################
#
# Before running this script:
# 1. Change the values of the global variables in the "GLOBAL VARIABLES" section
#    as necessary. Please read the notes attached to each when changing the value.
# 2. Reminder: If you change the value of any of the global variables, please
#    re-run the "GLOBAL VARIABLES" section before executing any code that uses
#    the global variable you changed or updated.
#
# When running this script:
# 1. Messages will print out to the terminal to indicate where the code is
#    currently at during execution.
# 2. If the webpage does not load when Chrome Driver starts, please manually
#    reload the page in the same window until the webpage loads. If the webpage
#    is appearing to take a long time to load, please try manually refreshing the
#    page until it loads.
# 3. Please allow the webpage to fully load before moving on.
# 4. Suggestion: After the page loads, please manually pause the video if you do
#    not want it to play while the script runs the next pieces of code.
# 5. Reminder: Please manually scroll down the page past the description to get the
#    first few comments to load before executing the piece of code to scroll to
#    the very bottom of the page.
#
#####################################################################################

# %%
##### IMPORTING PACKAGES ############################################################
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.keys import Keys
import pandas as pd
import os
import re
import string
import time
#####################################################################################

# %%
##### GLOBAL VARIABLES ##############################################################

# Path to where you have Chrome Driver installed (CHANGE AS NEEDED)
# Type: string
# Note: Please end it with "/chromedriver" (assuming "chromedriver" is the name of the file)
chromedriver = "/Users/kathleen.trinh/Documents/chromedriver.exe"

# Timeout for (CHANGE AS NEEDED depending on strength of Internet connection)
# Type: integer
# Note: This is used in driver.set_page_load_timeout(timeout_for)
# where the page will timeout after timeout_for seconds.
# The timeout is needed to move on with the script, as the page will take
# a long time to load, and we only need the text on the page to load.
timeout_for = 60

# Time to sleep for (CHANGE AS NEEDED depending on strength of Internet connection)
# Type: integer
# Note: This is used in function: time.sleep(time_to_sleep)
# where the code will pause for time_to_sleep seconds, allowing page to load.
# You may insert this function where needed if script does not run well as is.
time_to_sleep_for = 2

# Path to the folder you want to save the file in (CHANGE AS NEEDED)
# Type: string
path_to_folder = "C://Users/kathleen.trinh/Documents/Nissan/LEAF/YouTube/"

# URL of the video page you want to scrape (CHANGE AS NEEDED)
# Type: string
myURL = "https://www.youtube.com/watch?v=ZH7V2tU3iFc"

# File name you want to save the file as (CHANGE AS NEEDED)
# Type: string
# Note: Please end it with ".csv"
f_timestamp = "211013_14-51-PM"
v_code = myURL.split("v=")[1]
v_title = "We drove these electric cars until they DIED!"
filename = f_timestamp + "_YouTube_" + v_code + "_" + v_title + ".csv"

#####################################################################################

# %%
##### FUNCTIONS FOR PART 1: SHOWING ALL COMMENTS ON THE PAGE ########################

def scroll_to_bottom():
    print("Scrolling to bottom of page...")
    last_height = driver.execute_script("return document.documentElement.scrollHeight")
    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        # Wait to load page
        time.sleep(5)
        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break
        else:
            last_height = new_height
    print("Finished scrolling to bottom of page\n")

# %%
def get_viewXreplies_elements():
    found_elements = driver.find_elements_by_css_selector('#text')
    viewXreplies_elements = []
    for element in found_elements:
        match = re.match("(View).*(repl).*", element.text)
        if match:
            viewXreplies_elements.append(element)
    print("-----", len(viewXreplies_elements), "'View [x] replies' OR 'View reply' elements found -----\n")
    return viewXreplies_elements

def click_viewXreplies():
    viewXreplies_elements = get_viewXreplies_elements()
    if len(viewXreplies_elements) == 0:
        print("No 'View [x] replies' OR 'View reply' buttons detected\n")
    else:
        counter = 1
        for element in viewXreplies_elements:
            try:
                print(counter, ". Attempting to click 'View [x] replies' OR 'View reply' button #", counter, "...")
                driver.execute_script("arguments[0].scrollIntoView();", element)
                time.sleep(2)
                driver.execute_script("window.scrollBy(0, -60);")
                time.sleep(0.5)
                element.click()
            except NoSuchElementException as e:
                print(counter, ". NoSuchElementException occurred trying to click 'View [x] replies' OR 'View reply' button #", counter)
                print("Please execute this piece of code again OR reload page and try again")
                break
            except StaleElementReferenceException as e:
                print(counter, ". StaleElementReferenceException occurred trying to click 'View [x] replies' OR 'View reply' button #", counter)
                print("Please reload page and try again")
                break
            except:
                print(counter, ". Unknown error occurred trying to click 'View [x] replies' OR 'View reply' button #", counter)
                print("Please reload page and try again")
                break
            finally:
                time.sleep(2)
                counter += 1

# %%
def get_ShowMoreReplies_elements():
    found_elements = driver.find_elements_by_css_selector('#continuation > yt-next-continuation > paper-button > yt-formatted-string')
    viewXreplies_elements = []
    for element in found_elements:
        if element.text == "Show more replies":
            viewXreplies_elements.append(element)
    print("\n-----", len(viewXreplies_elements), "'Show more replies' elements found -----\n")
    return viewXreplies_elements

def click_ShowMoreReplies(ShowMoreReplies_elements):
    counter = 1
    for element in ShowMoreReplies_elements:
        try:
            print(counter, ". Attempting to click 'Show more replies' button #", counter, "...")
            driver.execute_script("arguments[0].scrollIntoView();", element)
            time.sleep(2)
            driver.execute_script("window.scrollBy(0, -60);")
            time.sleep(0.5)
            element.click()
        except NoSuchElementException as e:
            print(counter, ". NoSuchElementException occurred trying to click 'View [x] replies' OR 'View reply' button #", counter)
            print("Please (a) execute this piece of code again OR (b) reload page and try again")
            return -1
        except StaleElementReferenceException as e:
            print(counter, ". StaleElementReferenceException occurred trying to click 'Show more replies' button #", counter)
            print("Please reload page and try again")
            return -2
        except:
            print(counter, ". Error occurred trying to click 'Show more replies' button #", counter)
            print("Please reload page and try again")
            return -3
        finally:
            time.sleep(2)
            counter += 1
    return 0

def click_ALL_ShowMoreReplies():
    ShowMoreReplies_elements = get_ShowMoreReplies_elements()
    if len(ShowMoreReplies_elements) == 0:
        print("No 'Show more replies' buttons detected\n")
    else:
        finding_replies = True
        while finding_replies == True:
            result = click_ShowMoreReplies(ShowMoreReplies_elements)
            # Check if error occurred
            if result < 0:
                finding_replies = False
            # Check if there is a need for consequent iteration (any more 'Show more replies' buttons)
            ShowMoreReplies_elements = get_ShowMoreReplies_elements()
            if len(ShowMoreReplies_elements) == 0:
                print("No more 'Show more replies' buttons detected\n")
                finding_replies = False
            else:
                pass

# %%
##### FUNCTIONS FOR PART 2: POST DATA EXTRACTION ####################################

def get_video_title():
    print("Getting video title...")
    title_element = driver.find_element_by_xpath('//*[@id="container"]/h1/yt-formatted-string')
    title = title_element.text
    print("Video title:", title)
    return title

def get_normal_usernames():
    print("Attempting to get normal usernames...")
    username_elements = driver.find_elements_by_xpath('//*[@id="author-text"]/span')
    print("\tLength of username_elements =", len(username_elements))
    usernames = []
    for element in username_elements:
        usernames.append(element.text)
    print("\tLength of usernames =", len(usernames))
    return usernames

def get_styled_usernames():
    print("Attempting to get styled usernames...")
    styled_username_elements = driver.find_elements_by_xpath('//*[@id="name"]/yt-formatted-string')
    print("\tLength of styled_username_elements =", len(styled_username_elements))
    styled_usernames = []
    for element in styled_username_elements:
        styled_usernames.append(element.text)
    print("\tLength of styled_usernames =", len(styled_usernames))
    return styled_usernames

def count_empty_usernames(usernames):
    print("Counting empty usernames in normal_usernames...")
    count = 0
    for name in usernames:
        if len(name) == 0:
            count += 1
    print("\tNumber of empty usernames in normal_usernames =", count)
    return count

def get_ALL_usernames():
    print("Attempting to get ALL usernames...")
    normal_usernames = get_normal_usernames()
    num_empty_usernames = count_empty_usernames(normal_usernames)
    if num_empty_usernames == 0:
        print("\tNo empty usernames found")
        return normal_usernames
    else:
        styled_usernames = get_styled_usernames()
        if len(styled_usernames) == num_empty_usernames:
            print("\tNumber of found styled usernames = number of empty usernames? -- True")
            print("Replacing empty usernames and generating new usernames list...")
            usernames = []
            i = 0
            for name in normal_usernames:
                if len(name) > 0:
                    usernames.append(name)
                else:
                    usernames.append(styled_usernames[i])
            if len(usernames) == len(normal_usernames):
                print("\tLength of usernames = normal_usernames? -- True")
                print("Successfully replaced empty usernames with styled usernames")
                return usernames
            else:
                print("\tLength of usernames = normal_usernames? -- False")
                print("\t\tUnable to replace all empty usernames -- returning normal_usernames")
                return normal_usernames
        else:
            print("\tNumber of found styled usernames = number of empty usernames? -- False")
            print("\t\tLeaving empty usernames as is")
            return normal_usernames

def get_ALL_timestamps():
    print("Attempting to get ALL timestamps...")
    # //*[@id="header-author"]/yt-formatted-string/a
    timestamp_elements = driver.find_elements_by_xpath('//*[@id="header-author"]/yt-formatted-string/a')
    print("Length of timestamp_elements =", len(timestamp_elements))
    timestamps = []
    for element in timestamp_elements:
        timestamps.append(element.text)
    print("Length of timestamps =", len(timestamps))
    return timestamps

def parse_timestamp(timestamp_str):
    timestamp_split = timestamp_str.split()
    timestamp_number = timestamp_split[0]
    timestamp_unit = timestamp_split[1]
    timestamp_edited = "No"
    if timestamp_split[-1] == "(edited)":
        #print("Edited post detected")
        timestamp_edited = "Yes"
    parsed_timestamp = (timestamp_number, timestamp_unit, timestamp_edited)
    return parsed_timestamp

def get_ALL_parsed_timestamps(timestamps):
    print("Attempting to get ALL parsed timestamp data...")
    timestamp_numbers = []
    timestamp_units = []
    timestamp_edited = []
    for timestamp in timestamps:
        parsed_timestamp = parse_timestamp(timestamp)
        timestamp_numbers.append(parsed_timestamp[0])
        timestamp_units.append(parsed_timestamp[1])
        timestamp_edited.append(parsed_timestamp[2])
    parsed_timestamps = (timestamp_numbers, timestamp_units, timestamp_edited)
    print("Length of timestamp_numbers =", len(parsed_timestamps[0]))
    print("Length of timestamp_units =", len(parsed_timestamps[1]))
    print("Length of timestamp_edited =", len(parsed_timestamps[2]))
    return parsed_timestamps

# NOTE: This get_ALL_comments function is unable to get a URL/link inside of a comment.
#       Example: See Ade Yudha's comment on this video -- https://www.youtube.com/watch?reload=9&v=LmcciZ50nPs
def get_ALL_comments():
    print("Attempting to get ALL comments...")
    comment_elements = driver.find_elements_by_xpath('//*[@id="content-text"]')
    print("Length of comment_elements =", len(comment_elements))
    comments = []
    for element in comment_elements:
        comments.append(element.text)
    print("Length of comments =", len(comments))
    return comments

def get_ALL_upvotes():
    print("Attempting to get ALL upvotes...")
    upvote_elements = driver.find_elements_by_xpath('//*[@id="vote-count-middle"]')
    print("Length of upvote_elements =", len(upvote_elements))
    upvotes = []
    for element in upvote_elements:
        num_votes = element.text
        if len(num_votes) > 0:
            upvotes.append(num_votes)
        else:
            upvotes.append("0")
    print("Length of upvotes =", len(upvotes))
    return upvotes

# %%
##### FUNCTIONS FOR PART 3: DATA ADDITION ###########################################

def make_MyCommentIDs(comment_count):
    comment_IDs = []
    for i in range(1, (comment_count + 1)):
        comment_ID = "YT_" + v_code + "_Com" + str(i)
        comment_IDs.append(comment_ID)
    return comment_IDs

def make_sources(comment_count):
    sources = ["YouTube" for x in range(0, comment_count)]
    return sources

def make_video_titles(comment_count, title):
    titles = [title for x in range(0, comment_count)]
    return titles

def make_URLs(comment_count):
    URLs = [myURL for x in range(0, comment_count)]
    return URLs

# %%
##### IMPLEMENTATION ################################################################

# Setting up the Chrome Driver
print("Setting up Chrome Driver...\n")
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
# Out:
# Setting up Chrome Driver...

# %%
# Open URL with a timeout
try:
    print("Attempting to open URL:", myURL, "\n")
    driver.set_page_load_timeout(timeout_for)
    driver.get(myURL)
except TimeoutException as ex:
    isrunning = 0
    print("TimeoutException has been thrown. " + str(ex))
# Out:
# Attempting to open URL: https://www.youtube.com/watch?v=ZH7V2tU3iFc

# %%
# Print the following instructions to users:
print("TO USER:")
print("\t1. Please click on the 'Skip Ad' button inside the video player and/or pause the video if ")
print("\t   you do not want the video to play as you are scraping the page, as you cannot interrupt ")
print("\t   the Chrome Driver window by scrolling or clicking while the script is running.")
print("\t2. If the pop-up for Subscribing to YouTube Premium pops up in the bottom left-hand corner, ")
print("\t   please click the 'No Thanks' button.")
print("\t3. Please manually scroll down the page enough to load the first few comments before ")
print("\t   executing the line of code to automatically scroll down to the bottom of the page.")
print("\t4. Please keep in mind that the following line of code will not always successfully scroll ")
print("\t   down to the bottom of the page on the first try, as it may stop and seem finished ")
print("\t   if comments take a long time to load. If this is the case, please execute the line of ")
print("\t   multiple times until it truly scrolls to the bottom.")
# Out:
# TO USER:
# 	1. Please click on the 'Skip Ad' button inside the video player and/or pause the video if
# 	   you do not want the video to play as you are scraping the page, as you cannot interrupt
# 	   the Chrome Driver window by scrolling or clicking while the script is running.
# 	2. If the pop-up for Subscribing to YouTube Premium pops up in the bottom left-hand corner,
# 	   please click the 'No Thanks' button.
# 	3. Please manually scroll down the page enough to load the first few comments before
# 	   executing the line of code to automatically scroll down to the bottom of the page.
# 	4. Please keep in mind that the following line of code will not always successfully scroll
# 	   down to the bottom of the page on the first try, as it may stop and seem finished
# 	   if comments take a long time to load. If this is the case, please execute the line of
# 	   multiple times until it truly scrolls to the bottom.

# %%
# Please manually scroll down the page to get the first few comments to load,
# then execute the following line of code.

# Scroll to the bottom of the page to reveal all comments...
# May need to call this function multiple times depending on quality of Internet connection
# as the programmed wait time is not long enough to allow content to load.
scroll_to_bottom()
# Out:
# Scrolling to bottom of page...
# Finished scrolling to bottom of page

# %%
# Get total number of comments
# Note: Currently, I don't know what will happen if the video has 0 comments.
# XPath to "[x] Comments" below video description: //*[@id="count"]/yt-formatted-string
num_comments_element = driver.find_elements_by_xpath('//*[@id="count"]/yt-formatted-string')[0]
num_comments = num_comments_element.text
num_comments = num_comments.split()[0]
print(num_comments)
# Out:
# 13,837

# %%
# Click on "View [x] replies"
# Case for 1 reply: "View reply"
# Case for multiple replies: "View [x] replies"
click_viewXreplies()
# Out:
# ----- 575 'View [x] replies' OR 'View reply' elements found -----
#
# 1 . Attempting to click 'View [x] replies' OR 'View reply' button # 1 ...
# 2 . Attempting to click 'View [x] replies' OR 'View reply' button # 2 ...
# 3 . Attempting to click 'View [x] replies' OR 'View reply' button # 3 ...
# 4 . Attempting to click 'View [x] replies' OR 'View reply' button # 4 ...
# 5 . Attempting to click 'View [x] replies' OR 'View reply' button # 5 ...
# 6 . Attempting to click 'View [x] replies' OR 'View reply' button # 6 ...
# 7 . Attempting to click 'View [x] replies' OR 'View reply' button # 7 ...
# 8 . Attempting to click 'View [x] replies' OR 'View reply' button # 8 ...
# 9 . Attempting to click 'View [x] replies' OR 'View reply' button # 9 ...
# 10 . Attempting to click 'View [x] replies' OR 'View reply' button # 10 ...
# 11 . Attempting to click 'View [x] replies' OR 'View reply' button # 11 ...
# 12 . Attempting to click 'View [x] replies' OR 'View reply' button # 12 ...
# 13 . Attempting to click 'View [x] replies' OR 'View reply' button # 13 ...
# 14 . Attempting to click 'View [x] replies' OR 'View reply' button # 14 ...
# 15 . Attempting to click 'View [x] replies' OR 'View reply' button # 15 ...
# 16 . Attempting to click 'View [x] replies' OR 'View reply' button # 16 ...
# 17 . Attempting to click 'View [x] replies' OR 'View reply' button # 17 ...
# 18 . Attempting to click 'View [x] replies' OR 'View reply' button # 18 ...
# 19 . Attempting to click 'View [x] replies' OR 'View reply' button # 19 ...
# 20 . Attempting to click 'View [x] replies' OR 'View reply' button # 20 ...
# 21 . Attempting to click 'View [x] replies' OR 'View reply' button # 21 ...
# 22 . Attempting to click 'View [x] replies' OR 'View reply' button # 22 ...
# 23 . Attempting to click 'View [x] replies' OR 'View reply' button # 23 ...
# 24 . Attempting to click 'View [x] replies' OR 'View reply' button # 24 ...
# 25 . Attempting to click 'View [x] replies' OR 'View reply' button # 25 ...
# 26 . Attempting to click 'View [x] replies' OR 'View reply' button # 26 ...
# 27 . Attempting to click 'View [x] replies' OR 'View reply' button # 27 ...
# 28 . Attempting to click 'View [x] replies' OR 'View reply' button # 28 ...
# 29 . Attempting to click 'View [x] replies' OR 'View reply' button # 29 ...
# 30 . Attempting to click 'View [x] replies' OR 'View reply' button # 30 ...
# 31 . Attempting to click 'View [x] replies' OR 'View reply' button # 31 ...
# 32 . Attempting to click 'View [x] replies' OR 'View reply' button # 32 ...
# 33 . Attempting to click 'View [x] replies' OR 'View reply' button # 33 ...
# 34 . Attempting to click 'View [x] replies' OR 'View reply' button # 34 ...
# 35 . Attempting to click 'View [x] replies' OR 'View reply' button # 35 ...
# 36 . Attempting to click 'View [x] replies' OR 'View reply' button # 36 ...
# 37 . Attempting to click 'View [x] replies' OR 'View reply' button # 37 ...
# 38 . Attempting to click 'View [x] replies' OR 'View reply' button # 38 ...
# 39 . Attempting to click 'View [x] replies' OR 'View reply' button # 39 ...
# 40 . Attempting to click 'View [x] replies' OR 'View reply' button # 40 ...
# 41 . Attempting to click 'View [x] replies' OR 'View reply' button # 41 ...
# 42 . Attempting to click 'View [x] replies' OR 'View reply' button # 42 ...
# 43 . Attempting to click 'View [x] replies' OR 'View reply' button # 43 ...
# 44 . Attempting to click 'View [x] replies' OR 'View reply' button # 44 ...
# 45 . Attempting to click 'View [x] replies' OR 'View reply' button # 45 ...
# 46 . Attempting to click 'View [x] replies' OR 'View reply' button # 46 ...
# 47 . Attempting to click 'View [x] replies' OR 'View reply' button # 47 ...
# 48 . Attempting to click 'View [x] replies' OR 'View reply' button # 48 ...
# 49 . Attempting to click 'View [x] replies' OR 'View reply' button # 49 ...
# 50 . Attempting to click 'View [x] replies' OR 'View reply' button # 50 ...
# 51 . Attempting to click 'View [x] replies' OR 'View reply' button # 51 ...
# 52 . Attempting to click 'View [x] replies' OR 'View reply' button # 52 ...
# 53 . Attempting to click 'View [x] replies' OR 'View reply' button # 53 ...
# 54 . Attempting to click 'View [x] replies' OR 'View reply' button # 54 ...
# 55 . Attempting to click 'View [x] replies' OR 'View reply' button # 55 ...
# 56 . Attempting to click 'View [x] replies' OR 'View reply' button # 56 ...
# 57 . Attempting to click 'View [x] replies' OR 'View reply' button # 57 ...
# 58 . Attempting to click 'View [x] replies' OR 'View reply' button # 58 ...
# 59 . Attempting to click 'View [x] replies' OR 'View reply' button # 59 ...
# 60 . Attempting to click 'View [x] replies' OR 'View reply' button # 60 ...
# 61 . Attempting to click 'View [x] replies' OR 'View reply' button # 61 ...
# 62 . Attempting to click 'View [x] replies' OR 'View reply' button # 62 ...
# 63 . Attempting to click 'View [x] replies' OR 'View reply' button # 63 ...
# 64 . Attempting to click 'View [x] replies' OR 'View reply' button # 64 ...
# 65 . Attempting to click 'View [x] replies' OR 'View reply' button # 65 ...
# 66 . Attempting to click 'View [x] replies' OR 'View reply' button # 66 ...
# 67 . Attempting to click 'View [x] replies' OR 'View reply' button # 67 ...
# 68 . Attempting to click 'View [x] replies' OR 'View reply' button # 68 ...
# 69 . Attempting to click 'View [x] replies' OR 'View reply' button # 69 ...
# 70 . Attempting to click 'View [x] replies' OR 'View reply' button # 70 ...
# 71 . Attempting to click 'View [x] replies' OR 'View reply' button # 71 ...
# 72 . Attempting to click 'View [x] replies' OR 'View reply' button # 72 ...
# 73 . Attempting to click 'View [x] replies' OR 'View reply' button # 73 ...
# 74 . Attempting to click 'View [x] replies' OR 'View reply' button # 74 ...
# 75 . Attempting to click 'View [x] replies' OR 'View reply' button # 75 ...
# 76 . Attempting to click 'View [x] replies' OR 'View reply' button # 76 ...
# 77 . Attempting to click 'View [x] replies' OR 'View reply' button # 77 ...
# 78 . Attempting to click 'View [x] replies' OR 'View reply' button # 78 ...
# 79 . Attempting to click 'View [x] replies' OR 'View reply' button # 79 ...
# 80 . Attempting to click 'View [x] replies' OR 'View reply' button # 80 ...
# 81 . Attempting to click 'View [x] replies' OR 'View reply' button # 81 ...
# 82 . Attempting to click 'View [x] replies' OR 'View reply' button # 82 ...
# 83 . Attempting to click 'View [x] replies' OR 'View reply' button # 83 ...
# 84 . Attempting to click 'View [x] replies' OR 'View reply' button # 84 ...
# 85 . Attempting to click 'View [x] replies' OR 'View reply' button # 85 ...
# 86 . Attempting to click 'View [x] replies' OR 'View reply' button # 86 ...
# 87 . Attempting to click 'View [x] replies' OR 'View reply' button # 87 ...
# 88 . Attempting to click 'View [x] replies' OR 'View reply' button # 88 ...
# 89 . Attempting to click 'View [x] replies' OR 'View reply' button # 89 ...
# 90 . Attempting to click 'View [x] replies' OR 'View reply' button # 90 ...
# 91 . Attempting to click 'View [x] replies' OR 'View reply' button # 91 ...
# 92 . Attempting to click 'View [x] replies' OR 'View reply' button # 92 ...
# 93 . Attempting to click 'View [x] replies' OR 'View reply' button # 93 ...
# 94 . Attempting to click 'View [x] replies' OR 'View reply' button # 94 ...
# 95 . Attempting to click 'View [x] replies' OR 'View reply' button # 95 ...
# 96 . Attempting to click 'View [x] replies' OR 'View reply' button # 96 ...
# 97 . Attempting to click 'View [x] replies' OR 'View reply' button # 97 ...
# 98 . Attempting to click 'View [x] replies' OR 'View reply' button # 98 ...
# 99 . Attempting to click 'View [x] replies' OR 'View reply' button # 99 ...
# 100 . Attempting to click 'View [x] replies' OR 'View reply' button # 100 ...
# 101 . Attempting to click 'View [x] replies' OR 'View reply' button # 101 ...
# 102 . Attempting to click 'View [x] replies' OR 'View reply' button # 102 ...
# 103 . Attempting to click 'View [x] replies' OR 'View reply' button # 103 ...
# 104 . Attempting to click 'View [x] replies' OR 'View reply' button # 104 ...
# 105 . Attempting to click 'View [x] replies' OR 'View reply' button # 105 ...
# 106 . Attempting to click 'View [x] replies' OR 'View reply' button # 106 ...
# 107 . Attempting to click 'View [x] replies' OR 'View reply' button # 107 ...
# 108 . Attempting to click 'View [x] replies' OR 'View reply' button # 108 ...
# 109 . Attempting to click 'View [x] replies' OR 'View reply' button # 109 ...
# 110 . Attempting to click 'View [x] replies' OR 'View reply' button # 110 ...
# 111 . Attempting to click 'View [x] replies' OR 'View reply' button # 111 ...
# 112 . Attempting to click 'View [x] replies' OR 'View reply' button # 112 ...
# 113 . Attempting to click 'View [x] replies' OR 'View reply' button # 113 ...
# 114 . Attempting to click 'View [x] replies' OR 'View reply' button # 114 ...
# 115 . Attempting to click 'View [x] replies' OR 'View reply' button # 115 ...
# 116 . Attempting to click 'View [x] replies' OR 'View reply' button # 116 ...
# 117 . Attempting to click 'View [x] replies' OR 'View reply' button # 117 ...
# 118 . Attempting to click 'View [x] replies' OR 'View reply' button # 118 ...
# 119 . Attempting to click 'View [x] replies' OR 'View reply' button # 119 ...
# 120 . Attempting to click 'View [x] replies' OR 'View reply' button # 120 ...
# 121 . Attempting to click 'View [x] replies' OR 'View reply' button # 121 ...
# 122 . Attempting to click 'View [x] replies' OR 'View reply' button # 122 ...
# 123 . Attempting to click 'View [x] replies' OR 'View reply' button # 123 ...
# 124 . Attempting to click 'View [x] replies' OR 'View reply' button # 124 ...
# 125 . Attempting to click 'View [x] replies' OR 'View reply' button # 125 ...
# 126 . Attempting to click 'View [x] replies' OR 'View reply' button # 126 ...
# 127 . Attempting to click 'View [x] replies' OR 'View reply' button # 127 ...
# 128 . Attempting to click 'View [x] replies' OR 'View reply' button # 128 ...
# 129 . Attempting to click 'View [x] replies' OR 'View reply' button # 129 ...
# 130 . Attempting to click 'View [x] replies' OR 'View reply' button # 130 ...
# 131 . Attempting to click 'View [x] replies' OR 'View reply' button # 131 ...
# 132 . Attempting to click 'View [x] replies' OR 'View reply' button # 132 ...
# 133 . Attempting to click 'View [x] replies' OR 'View reply' button # 133 ...
# 134 . Attempting to click 'View [x] replies' OR 'View reply' button # 134 ...
# 135 . Attempting to click 'View [x] replies' OR 'View reply' button # 135 ...
# 136 . Attempting to click 'View [x] replies' OR 'View reply' button # 136 ...
# 137 . Attempting to click 'View [x] replies' OR 'View reply' button # 137 ...
# 138 . Attempting to click 'View [x] replies' OR 'View reply' button # 138 ...
# 139 . Attempting to click 'View [x] replies' OR 'View reply' button # 139 ...
# 140 . Attempting to click 'View [x] replies' OR 'View reply' button # 140 ...
# 141 . Attempting to click 'View [x] replies' OR 'View reply' button # 141 ...
# 142 . Attempting to click 'View [x] replies' OR 'View reply' button # 142 ...
# 143 . Attempting to click 'View [x] replies' OR 'View reply' button # 143 ...
# 144 . Attempting to click 'View [x] replies' OR 'View reply' button # 144 ...
# 145 . Attempting to click 'View [x] replies' OR 'View reply' button # 145 ...
# 146 . Attempting to click 'View [x] replies' OR 'View reply' button # 146 ...
# 147 . Attempting to click 'View [x] replies' OR 'View reply' button # 147 ...
# 148 . Attempting to click 'View [x] replies' OR 'View reply' button # 148 ...
# 149 . Attempting to click 'View [x] replies' OR 'View reply' button # 149 ...
# 150 . Attempting to click 'View [x] replies' OR 'View reply' button # 150 ...
# 151 . Attempting to click 'View [x] replies' OR 'View reply' button # 151 ...
# 152 . Attempting to click 'View [x] replies' OR 'View reply' button # 152 ...
# 153 . Attempting to click 'View [x] replies' OR 'View reply' button # 153 ...
# 154 . Attempting to click 'View [x] replies' OR 'View reply' button # 154 ...
# 155 . Attempting to click 'View [x] replies' OR 'View reply' button # 155 ...
# 156 . Attempting to click 'View [x] replies' OR 'View reply' button # 156 ...
# 157 . Attempting to click 'View [x] replies' OR 'View reply' button # 157 ...
# 158 . Attempting to click 'View [x] replies' OR 'View reply' button # 158 ...
# 159 . Attempting to click 'View [x] replies' OR 'View reply' button # 159 ...
# 160 . Attempting to click 'View [x] replies' OR 'View reply' button # 160 ...
# 161 . Attempting to click 'View [x] replies' OR 'View reply' button # 161 ...
# 162 . Attempting to click 'View [x] replies' OR 'View reply' button # 162 ...
# 163 . Attempting to click 'View [x] replies' OR 'View reply' button # 163 ...
# 164 . Attempting to click 'View [x] replies' OR 'View reply' button # 164 ...
# 165 . Attempting to click 'View [x] replies' OR 'View reply' button # 165 ...
# 166 . Attempting to click 'View [x] replies' OR 'View reply' button # 166 ...
# 167 . Attempting to click 'View [x] replies' OR 'View reply' button # 167 ...
# 168 . Attempting to click 'View [x] replies' OR 'View reply' button # 168 ...
# 169 . Attempting to click 'View [x] replies' OR 'View reply' button # 169 ...
# 170 . Attempting to click 'View [x] replies' OR 'View reply' button # 170 ...
# 171 . Attempting to click 'View [x] replies' OR 'View reply' button # 171 ...
# 172 . Attempting to click 'View [x] replies' OR 'View reply' button # 172 ...
# 173 . Attempting to click 'View [x] replies' OR 'View reply' button # 173 ...
# 174 . Attempting to click 'View [x] replies' OR 'View reply' button # 174 ...
# 175 . Attempting to click 'View [x] replies' OR 'View reply' button # 175 ...
# 176 . Attempting to click 'View [x] replies' OR 'View reply' button # 176 ...
# 177 . Attempting to click 'View [x] replies' OR 'View reply' button # 177 ...
# 178 . Attempting to click 'View [x] replies' OR 'View reply' button # 178 ...
# 179 . Attempting to click 'View [x] replies' OR 'View reply' button # 179 ...
# 180 . Attempting to click 'View [x] replies' OR 'View reply' button # 180 ...
# 181 . Attempting to click 'View [x] replies' OR 'View reply' button # 181 ...
# 182 . Attempting to click 'View [x] replies' OR 'View reply' button # 182 ...
# 183 . Attempting to click 'View [x] replies' OR 'View reply' button # 183 ...
# 184 . Attempting to click 'View [x] replies' OR 'View reply' button # 184 ...
# 185 . Attempting to click 'View [x] replies' OR 'View reply' button # 185 ...
# 186 . Attempting to click 'View [x] replies' OR 'View reply' button # 186 ...
# 187 . Attempting to click 'View [x] replies' OR 'View reply' button # 187 ...
# 188 . Attempting to click 'View [x] replies' OR 'View reply' button # 188 ...
# 189 . Attempting to click 'View [x] replies' OR 'View reply' button # 189 ...
# 190 . Attempting to click 'View [x] replies' OR 'View reply' button # 190 ...
# 191 . Attempting to click 'View [x] replies' OR 'View reply' button # 191 ...
# 192 . Attempting to click 'View [x] replies' OR 'View reply' button # 192 ...
# 193 . Attempting to click 'View [x] replies' OR 'View reply' button # 193 ...
# 194 . Attempting to click 'View [x] replies' OR 'View reply' button # 194 ...
# 195 . Attempting to click 'View [x] replies' OR 'View reply' button # 195 ...
# 196 . Attempting to click 'View [x] replies' OR 'View reply' button # 196 ...
# 197 . Attempting to click 'View [x] replies' OR 'View reply' button # 197 ...
# 198 . Attempting to click 'View [x] replies' OR 'View reply' button # 198 ...
# 199 . Attempting to click 'View [x] replies' OR 'View reply' button # 199 ...
# 200 . Attempting to click 'View [x] replies' OR 'View reply' button # 200 ...
# 201 . Attempting to click 'View [x] replies' OR 'View reply' button # 201 ...
# 202 . Attempting to click 'View [x] replies' OR 'View reply' button # 202 ...
# 203 . Attempting to click 'View [x] replies' OR 'View reply' button # 203 ...
# 204 . Attempting to click 'View [x] replies' OR 'View reply' button # 204 ...
# 205 . Attempting to click 'View [x] replies' OR 'View reply' button # 205 ...
# 206 . Attempting to click 'View [x] replies' OR 'View reply' button # 206 ...
# 207 . Attempting to click 'View [x] replies' OR 'View reply' button # 207 ...
# 208 . Attempting to click 'View [x] replies' OR 'View reply' button # 208 ...
# 209 . Attempting to click 'View [x] replies' OR 'View reply' button # 209 ...
# 210 . Attempting to click 'View [x] replies' OR 'View reply' button # 210 ...
# 211 . Attempting to click 'View [x] replies' OR 'View reply' button # 211 ...
# 212 . Attempting to click 'View [x] replies' OR 'View reply' button # 212 ...
# 213 . Attempting to click 'View [x] replies' OR 'View reply' button # 213 ...
# 214 . Attempting to click 'View [x] replies' OR 'View reply' button # 214 ...
# 215 . Attempting to click 'View [x] replies' OR 'View reply' button # 215 ...
# 216 . Attempting to click 'View [x] replies' OR 'View reply' button # 216 ...
# 217 . Attempting to click 'View [x] replies' OR 'View reply' button # 217 ...
# 218 . Attempting to click 'View [x] replies' OR 'View reply' button # 218 ...
# 219 . Attempting to click 'View [x] replies' OR 'View reply' button # 219 ...
# 220 . Attempting to click 'View [x] replies' OR 'View reply' button # 220 ...
# 221 . Attempting to click 'View [x] replies' OR 'View reply' button # 221 ...
# 222 . Attempting to click 'View [x] replies' OR 'View reply' button # 222 ...
# 223 . Attempting to click 'View [x] replies' OR 'View reply' button # 223 ...
# 224 . Attempting to click 'View [x] replies' OR 'View reply' button # 224 ...
# 225 . Attempting to click 'View [x] replies' OR 'View reply' button # 225 ...
# 226 . Attempting to click 'View [x] replies' OR 'View reply' button # 226 ...
# 227 . Attempting to click 'View [x] replies' OR 'View reply' button # 227 ...
# 228 . Attempting to click 'View [x] replies' OR 'View reply' button # 228 ...
# 229 . Attempting to click 'View [x] replies' OR 'View reply' button # 229 ...
# 230 . Attempting to click 'View [x] replies' OR 'View reply' button # 230 ...
# 231 . Attempting to click 'View [x] replies' OR 'View reply' button # 231 ...
# 232 . Attempting to click 'View [x] replies' OR 'View reply' button # 232 ...
# 233 . Attempting to click 'View [x] replies' OR 'View reply' button # 233 ...
# 234 . Attempting to click 'View [x] replies' OR 'View reply' button # 234 ...
# 235 . Attempting to click 'View [x] replies' OR 'View reply' button # 235 ...
# 236 . Attempting to click 'View [x] replies' OR 'View reply' button # 236 ...
# 237 . Attempting to click 'View [x] replies' OR 'View reply' button # 237 ...
# 238 . Attempting to click 'View [x] replies' OR 'View reply' button # 238 ...
# 239 . Attempting to click 'View [x] replies' OR 'View reply' button # 239 ...
# 240 . Attempting to click 'View [x] replies' OR 'View reply' button # 240 ...
# 241 . Attempting to click 'View [x] replies' OR 'View reply' button # 241 ...
# 242 . Attempting to click 'View [x] replies' OR 'View reply' button # 242 ...
# 243 . Attempting to click 'View [x] replies' OR 'View reply' button # 243 ...
# 244 . Attempting to click 'View [x] replies' OR 'View reply' button # 244 ...
# 245 . Attempting to click 'View [x] replies' OR 'View reply' button # 245 ...
# 246 . Attempting to click 'View [x] replies' OR 'View reply' button # 246 ...
# 247 . Attempting to click 'View [x] replies' OR 'View reply' button # 247 ...
# 248 . Attempting to click 'View [x] replies' OR 'View reply' button # 248 ...
# 249 . Attempting to click 'View [x] replies' OR 'View reply' button # 249 ...
# 250 . Attempting to click 'View [x] replies' OR 'View reply' button # 250 ...
# 251 . Attempting to click 'View [x] replies' OR 'View reply' button # 251 ...
# 252 . Attempting to click 'View [x] replies' OR 'View reply' button # 252 ...
# 253 . Attempting to click 'View [x] replies' OR 'View reply' button # 253 ...
# 254 . Attempting to click 'View [x] replies' OR 'View reply' button # 254 ...
# 255 . Attempting to click 'View [x] replies' OR 'View reply' button # 255 ...
# 256 . Attempting to click 'View [x] replies' OR 'View reply' button # 256 ...
# 257 . Attempting to click 'View [x] replies' OR 'View reply' button # 257 ...
# 258 . Attempting to click 'View [x] replies' OR 'View reply' button # 258 ...
# 259 . Attempting to click 'View [x] replies' OR 'View reply' button # 259 ...
# 260 . Attempting to click 'View [x] replies' OR 'View reply' button # 260 ...
# 261 . Attempting to click 'View [x] replies' OR 'View reply' button # 261 ...
# 262 . Attempting to click 'View [x] replies' OR 'View reply' button # 262 ...
# 263 . Attempting to click 'View [x] replies' OR 'View reply' button # 263 ...
# 264 . Attempting to click 'View [x] replies' OR 'View reply' button # 264 ...
# 265 . Attempting to click 'View [x] replies' OR 'View reply' button # 265 ...
# 266 . Attempting to click 'View [x] replies' OR 'View reply' button # 266 ...
# 267 . Attempting to click 'View [x] replies' OR 'View reply' button # 267 ...
# 268 . Attempting to click 'View [x] replies' OR 'View reply' button # 268 ...
# 269 . Attempting to click 'View [x] replies' OR 'View reply' button # 269 ...
# 270 . Attempting to click 'View [x] replies' OR 'View reply' button # 270 ...
# 271 . Attempting to click 'View [x] replies' OR 'View reply' button # 271 ...
# 272 . Attempting to click 'View [x] replies' OR 'View reply' button # 272 ...
# 273 . Attempting to click 'View [x] replies' OR 'View reply' button # 273 ...
# 274 . Attempting to click 'View [x] replies' OR 'View reply' button # 274 ...
# 275 . Attempting to click 'View [x] replies' OR 'View reply' button # 275 ...
# 276 . Attempting to click 'View [x] replies' OR 'View reply' button # 276 ...
# 277 . Attempting to click 'View [x] replies' OR 'View reply' button # 277 ...
# 278 . Attempting to click 'View [x] replies' OR 'View reply' button # 278 ...
# 279 . Attempting to click 'View [x] replies' OR 'View reply' button # 279 ...
# 280 . Attempting to click 'View [x] replies' OR 'View reply' button # 280 ...
# 281 . Attempting to click 'View [x] replies' OR 'View reply' button # 281 ...
# 282 . Attempting to click 'View [x] replies' OR 'View reply' button # 282 ...
# 283 . Attempting to click 'View [x] replies' OR 'View reply' button # 283 ...
# 284 . Attempting to click 'View [x] replies' OR 'View reply' button # 284 ...
# 285 . Attempting to click 'View [x] replies' OR 'View reply' button # 285 ...
# 286 . Attempting to click 'View [x] replies' OR 'View reply' button # 286 ...
# 287 . Attempting to click 'View [x] replies' OR 'View reply' button # 287 ...
# 288 . Attempting to click 'View [x] replies' OR 'View reply' button # 288 ...
# 289 . Attempting to click 'View [x] replies' OR 'View reply' button # 289 ...
# 290 . Attempting to click 'View [x] replies' OR 'View reply' button # 290 ...
# 291 . Attempting to click 'View [x] replies' OR 'View reply' button # 291 ...
# 292 . Attempting to click 'View [x] replies' OR 'View reply' button # 292 ...
# 293 . Attempting to click 'View [x] replies' OR 'View reply' button # 293 ...
# 294 . Attempting to click 'View [x] replies' OR 'View reply' button # 294 ...
# 295 . Attempting to click 'View [x] replies' OR 'View reply' button # 295 ...
# 296 . Attempting to click 'View [x] replies' OR 'View reply' button # 296 ...
# 297 . Attempting to click 'View [x] replies' OR 'View reply' button # 297 ...
# 298 . Attempting to click 'View [x] replies' OR 'View reply' button # 298 ...
# 299 . Attempting to click 'View [x] replies' OR 'View reply' button # 299 ...
# 300 . Attempting to click 'View [x] replies' OR 'View reply' button # 300 ...
# 301 . Attempting to click 'View [x] replies' OR 'View reply' button # 301 ...
# 302 . Attempting to click 'View [x] replies' OR 'View reply' button # 302 ...
# 303 . Attempting to click 'View [x] replies' OR 'View reply' button # 303 ...
# 304 . Attempting to click 'View [x] replies' OR 'View reply' button # 304 ...
# 305 . Attempting to click 'View [x] replies' OR 'View reply' button # 305 ...
# 306 . Attempting to click 'View [x] replies' OR 'View reply' button # 306 ...
# 307 . Attempting to click 'View [x] replies' OR 'View reply' button # 307 ...
# 308 . Attempting to click 'View [x] replies' OR 'View reply' button # 308 ...
# 309 . Attempting to click 'View [x] replies' OR 'View reply' button # 309 ...
# 310 . Attempting to click 'View [x] replies' OR 'View reply' button # 310 ...
# 311 . Attempting to click 'View [x] replies' OR 'View reply' button # 311 ...
# 312 . Attempting to click 'View [x] replies' OR 'View reply' button # 312 ...
# 313 . Attempting to click 'View [x] replies' OR 'View reply' button # 313 ...
# 314 . Attempting to click 'View [x] replies' OR 'View reply' button # 314 ...
# 315 . Attempting to click 'View [x] replies' OR 'View reply' button # 315 ...
# 316 . Attempting to click 'View [x] replies' OR 'View reply' button # 316 ...
# 317 . Attempting to click 'View [x] replies' OR 'View reply' button # 317 ...
# 318 . Attempting to click 'View [x] replies' OR 'View reply' button # 318 ...
# 319 . Attempting to click 'View [x] replies' OR 'View reply' button # 319 ...
# 320 . Attempting to click 'View [x] replies' OR 'View reply' button # 320 ...
# 321 . Attempting to click 'View [x] replies' OR 'View reply' button # 321 ...
# 322 . Attempting to click 'View [x] replies' OR 'View reply' button # 322 ...
# 323 . Attempting to click 'View [x] replies' OR 'View reply' button # 323 ...
# 324 . Attempting to click 'View [x] replies' OR 'View reply' button # 324 ...
# 325 . Attempting to click 'View [x] replies' OR 'View reply' button # 325 ...
# 326 . Attempting to click 'View [x] replies' OR 'View reply' button # 326 ...
# 327 . Attempting to click 'View [x] replies' OR 'View reply' button # 327 ...
# 328 . Attempting to click 'View [x] replies' OR 'View reply' button # 328 ...
# 329 . Attempting to click 'View [x] replies' OR 'View reply' button # 329 ...
# 330 . Attempting to click 'View [x] replies' OR 'View reply' button # 330 ...
# 331 . Attempting to click 'View [x] replies' OR 'View reply' button # 331 ...
# 332 . Attempting to click 'View [x] replies' OR 'View reply' button # 332 ...
# 333 . Attempting to click 'View [x] replies' OR 'View reply' button # 333 ...
# 334 . Attempting to click 'View [x] replies' OR 'View reply' button # 334 ...
# 335 . Attempting to click 'View [x] replies' OR 'View reply' button # 335 ...
# 336 . Attempting to click 'View [x] replies' OR 'View reply' button # 336 ...
# 337 . Attempting to click 'View [x] replies' OR 'View reply' button # 337 ...
# 338 . Attempting to click 'View [x] replies' OR 'View reply' button # 338 ...
# 339 . Attempting to click 'View [x] replies' OR 'View reply' button # 339 ...
# 340 . Attempting to click 'View [x] replies' OR 'View reply' button # 340 ...
# 341 . Attempting to click 'View [x] replies' OR 'View reply' button # 341 ...
# 342 . Attempting to click 'View [x] replies' OR 'View reply' button # 342 ...
# 343 . Attempting to click 'View [x] replies' OR 'View reply' button # 343 ...
# 344 . Attempting to click 'View [x] replies' OR 'View reply' button # 344 ...
# 345 . Attempting to click 'View [x] replies' OR 'View reply' button # 345 ...
# 346 . Attempting to click 'View [x] replies' OR 'View reply' button # 346 ...
# 347 . Attempting to click 'View [x] replies' OR 'View reply' button # 347 ...
# 348 . Attempting to click 'View [x] replies' OR 'View reply' button # 348 ...
# 349 . Attempting to click 'View [x] replies' OR 'View reply' button # 349 ...
# 350 . Attempting to click 'View [x] replies' OR 'View reply' button # 350 ...
# 351 . Attempting to click 'View [x] replies' OR 'View reply' button # 351 ...
# 352 . Attempting to click 'View [x] replies' OR 'View reply' button # 352 ...
# 353 . Attempting to click 'View [x] replies' OR 'View reply' button # 353 ...
# 354 . Attempting to click 'View [x] replies' OR 'View reply' button # 354 ...
# 355 . Attempting to click 'View [x] replies' OR 'View reply' button # 355 ...
# 356 . Attempting to click 'View [x] replies' OR 'View reply' button # 356 ...
# 357 . Attempting to click 'View [x] replies' OR 'View reply' button # 357 ...
# 358 . Attempting to click 'View [x] replies' OR 'View reply' button # 358 ...
# 359 . Attempting to click 'View [x] replies' OR 'View reply' button # 359 ...
# 360 . Attempting to click 'View [x] replies' OR 'View reply' button # 360 ...
# 361 . Attempting to click 'View [x] replies' OR 'View reply' button # 361 ...
# 362 . Attempting to click 'View [x] replies' OR 'View reply' button # 362 ...
# 363 . Attempting to click 'View [x] replies' OR 'View reply' button # 363 ...
# 364 . Attempting to click 'View [x] replies' OR 'View reply' button # 364 ...
# 365 . Attempting to click 'View [x] replies' OR 'View reply' button # 365 ...
# 366 . Attempting to click 'View [x] replies' OR 'View reply' button # 366 ...
# 367 . Attempting to click 'View [x] replies' OR 'View reply' button # 367 ...
# 368 . Attempting to click 'View [x] replies' OR 'View reply' button # 368 ...
# 369 . Attempting to click 'View [x] replies' OR 'View reply' button # 369 ...
# 370 . Attempting to click 'View [x] replies' OR 'View reply' button # 370 ...
# 371 . Attempting to click 'View [x] replies' OR 'View reply' button # 371 ...
# 372 . Attempting to click 'View [x] replies' OR 'View reply' button # 372 ...
# 373 . Attempting to click 'View [x] replies' OR 'View reply' button # 373 ...
# 374 . Attempting to click 'View [x] replies' OR 'View reply' button # 374 ...
# 375 . Attempting to click 'View [x] replies' OR 'View reply' button # 375 ...
# 376 . Attempting to click 'View [x] replies' OR 'View reply' button # 376 ...
# 377 . Attempting to click 'View [x] replies' OR 'View reply' button # 377 ...
# 378 . Attempting to click 'View [x] replies' OR 'View reply' button # 378 ...
# 379 . Attempting to click 'View [x] replies' OR 'View reply' button # 379 ...
# 380 . Attempting to click 'View [x] replies' OR 'View reply' button # 380 ...
# 381 . Attempting to click 'View [x] replies' OR 'View reply' button # 381 ...
# 382 . Attempting to click 'View [x] replies' OR 'View reply' button # 382 ...
# 383 . Attempting to click 'View [x] replies' OR 'View reply' button # 383 ...
# 384 . Attempting to click 'View [x] replies' OR 'View reply' button # 384 ...
# 385 . Attempting to click 'View [x] replies' OR 'View reply' button # 385 ...
# 386 . Attempting to click 'View [x] replies' OR 'View reply' button # 386 ...
# 387 . Attempting to click 'View [x] replies' OR 'View reply' button # 387 ...
# 388 . Attempting to click 'View [x] replies' OR 'View reply' button # 388 ...
# 389 . Attempting to click 'View [x] replies' OR 'View reply' button # 389 ...
# 390 . Attempting to click 'View [x] replies' OR 'View reply' button # 390 ...
# 391 . Attempting to click 'View [x] replies' OR 'View reply' button # 391 ...
# 392 . Attempting to click 'View [x] replies' OR 'View reply' button # 392 ...
# 393 . Attempting to click 'View [x] replies' OR 'View reply' button # 393 ...
# 394 . Attempting to click 'View [x] replies' OR 'View reply' button # 394 ...
# 395 . Attempting to click 'View [x] replies' OR 'View reply' button # 395 ...
# 396 . Attempting to click 'View [x] replies' OR 'View reply' button # 396 ...
# 397 . Attempting to click 'View [x] replies' OR 'View reply' button # 397 ...
# 398 . Attempting to click 'View [x] replies' OR 'View reply' button # 398 ...
# 399 . Attempting to click 'View [x] replies' OR 'View reply' button # 399 ...
# 400 . Attempting to click 'View [x] replies' OR 'View reply' button # 400 ...
# 401 . Attempting to click 'View [x] replies' OR 'View reply' button # 401 ...
# 402 . Attempting to click 'View [x] replies' OR 'View reply' button # 402 ...
# 403 . Attempting to click 'View [x] replies' OR 'View reply' button # 403 ...
# 404 . Attempting to click 'View [x] replies' OR 'View reply' button # 404 ...
# 405 . Attempting to click 'View [x] replies' OR 'View reply' button # 405 ...
# 406 . Attempting to click 'View [x] replies' OR 'View reply' button # 406 ...
# 407 . Attempting to click 'View [x] replies' OR 'View reply' button # 407 ...
# 408 . Attempting to click 'View [x] replies' OR 'View reply' button # 408 ...
# 409 . Attempting to click 'View [x] replies' OR 'View reply' button # 409 ...
# 410 . Attempting to click 'View [x] replies' OR 'View reply' button # 410 ...
# 411 . Attempting to click 'View [x] replies' OR 'View reply' button # 411 ...
# 412 . Attempting to click 'View [x] replies' OR 'View reply' button # 412 ...
# 413 . Attempting to click 'View [x] replies' OR 'View reply' button # 413 ...
# 414 . Attempting to click 'View [x] replies' OR 'View reply' button # 414 ...
# 415 . Attempting to click 'View [x] replies' OR 'View reply' button # 415 ...
# 416 . Attempting to click 'View [x] replies' OR 'View reply' button # 416 ...
# 417 . Attempting to click 'View [x] replies' OR 'View reply' button # 417 ...
# 418 . Attempting to click 'View [x] replies' OR 'View reply' button # 418 ...
# 419 . Attempting to click 'View [x] replies' OR 'View reply' button # 419 ...
# 420 . Attempting to click 'View [x] replies' OR 'View reply' button # 420 ...
# 421 . Attempting to click 'View [x] replies' OR 'View reply' button # 421 ...
# 422 . Attempting to click 'View [x] replies' OR 'View reply' button # 422 ...
# 423 . Attempting to click 'View [x] replies' OR 'View reply' button # 423 ...
# 424 . Attempting to click 'View [x] replies' OR 'View reply' button # 424 ...
# 425 . Attempting to click 'View [x] replies' OR 'View reply' button # 425 ...
# 426 . Attempting to click 'View [x] replies' OR 'View reply' button # 426 ...
# 427 . Attempting to click 'View [x] replies' OR 'View reply' button # 427 ...
# 428 . Attempting to click 'View [x] replies' OR 'View reply' button # 428 ...
# 429 . Attempting to click 'View [x] replies' OR 'View reply' button # 429 ...
# 430 . Attempting to click 'View [x] replies' OR 'View reply' button # 430 ...
# 431 . Attempting to click 'View [x] replies' OR 'View reply' button # 431 ...
# 432 . Attempting to click 'View [x] replies' OR 'View reply' button # 432 ...
# 433 . Attempting to click 'View [x] replies' OR 'View reply' button # 433 ...
# 434 . Attempting to click 'View [x] replies' OR 'View reply' button # 434 ...
# 435 . Attempting to click 'View [x] replies' OR 'View reply' button # 435 ...
# 436 . Attempting to click 'View [x] replies' OR 'View reply' button # 436 ...
# 437 . Attempting to click 'View [x] replies' OR 'View reply' button # 437 ...
# 438 . Attempting to click 'View [x] replies' OR 'View reply' button # 438 ...
# 439 . Attempting to click 'View [x] replies' OR 'View reply' button # 439 ...
# 440 . Attempting to click 'View [x] replies' OR 'View reply' button # 440 ...
# 441 . Attempting to click 'View [x] replies' OR 'View reply' button # 441 ...
# 442 . Attempting to click 'View [x] replies' OR 'View reply' button # 442 ...
# 443 . Attempting to click 'View [x] replies' OR 'View reply' button # 443 ...
# 444 . Attempting to click 'View [x] replies' OR 'View reply' button # 444 ...
# 445 . Attempting to click 'View [x] replies' OR 'View reply' button # 445 ...
# 446 . Attempting to click 'View [x] replies' OR 'View reply' button # 446 ...
# 447 . Attempting to click 'View [x] replies' OR 'View reply' button # 447 ...
# 448 . Attempting to click 'View [x] replies' OR 'View reply' button # 448 ...
# 449 . Attempting to click 'View [x] replies' OR 'View reply' button # 449 ...
# 450 . Attempting to click 'View [x] replies' OR 'View reply' button # 450 ...
# 451 . Attempting to click 'View [x] replies' OR 'View reply' button # 451 ...
# 452 . Attempting to click 'View [x] replies' OR 'View reply' button # 452 ...
# 453 . Attempting to click 'View [x] replies' OR 'View reply' button # 453 ...
# 454 . Attempting to click 'View [x] replies' OR 'View reply' button # 454 ...
# 455 . Attempting to click 'View [x] replies' OR 'View reply' button # 455 ...
# 456 . Attempting to click 'View [x] replies' OR 'View reply' button # 456 ...
# 457 . Attempting to click 'View [x] replies' OR 'View reply' button # 457 ...
# 458 . Attempting to click 'View [x] replies' OR 'View reply' button # 458 ...
# 459 . Attempting to click 'View [x] replies' OR 'View reply' button # 459 ...
# 460 . Attempting to click 'View [x] replies' OR 'View reply' button # 460 ...
# 461 . Attempting to click 'View [x] replies' OR 'View reply' button # 461 ...
# 462 . Attempting to click 'View [x] replies' OR 'View reply' button # 462 ...
# 463 . Attempting to click 'View [x] replies' OR 'View reply' button # 463 ...
# 464 . Attempting to click 'View [x] replies' OR 'View reply' button # 464 ...
# 465 . Attempting to click 'View [x] replies' OR 'View reply' button # 465 ...
# 466 . Attempting to click 'View [x] replies' OR 'View reply' button # 466 ...
# 467 . Attempting to click 'View [x] replies' OR 'View reply' button # 467 ...
# 468 . Attempting to click 'View [x] replies' OR 'View reply' button # 468 ...
# 469 . Attempting to click 'View [x] replies' OR 'View reply' button # 469 ...
# 470 . Attempting to click 'View [x] replies' OR 'View reply' button # 470 ...
# 471 . Attempting to click 'View [x] replies' OR 'View reply' button # 471 ...
# 472 . Attempting to click 'View [x] replies' OR 'View reply' button # 472 ...
# 473 . Attempting to click 'View [x] replies' OR 'View reply' button # 473 ...
# 474 . Attempting to click 'View [x] replies' OR 'View reply' button # 474 ...
# 475 . Attempting to click 'View [x] replies' OR 'View reply' button # 475 ...
# 476 . Attempting to click 'View [x] replies' OR 'View reply' button # 476 ...
# 477 . Attempting to click 'View [x] replies' OR 'View reply' button # 477 ...
# 478 . Attempting to click 'View [x] replies' OR 'View reply' button # 478 ...
# 479 . Attempting to click 'View [x] replies' OR 'View reply' button # 479 ...
# 480 . Attempting to click 'View [x] replies' OR 'View reply' button # 480 ...
# 481 . Attempting to click 'View [x] replies' OR 'View reply' button # 481 ...
# 482 . Attempting to click 'View [x] replies' OR 'View reply' button # 482 ...
# 483 . Attempting to click 'View [x] replies' OR 'View reply' button # 483 ...
# 484 . Attempting to click 'View [x] replies' OR 'View reply' button # 484 ...
# 485 . Attempting to click 'View [x] replies' OR 'View reply' button # 485 ...
# 486 . Attempting to click 'View [x] replies' OR 'View reply' button # 486 ...
# 487 . Attempting to click 'View [x] replies' OR 'View reply' button # 487 ...
# 488 . Attempting to click 'View [x] replies' OR 'View reply' button # 488 ...
# 489 . Attempting to click 'View [x] replies' OR 'View reply' button # 489 ...
# 490 . Attempting to click 'View [x] replies' OR 'View reply' button # 490 ...
# 491 . Attempting to click 'View [x] replies' OR 'View reply' button # 491 ...
# 492 . Attempting to click 'View [x] replies' OR 'View reply' button # 492 ...
# 493 . Attempting to click 'View [x] replies' OR 'View reply' button # 493 ...
# 494 . Attempting to click 'View [x] replies' OR 'View reply' button # 494 ...
# 495 . Attempting to click 'View [x] replies' OR 'View reply' button # 495 ...
# 496 . Attempting to click 'View [x] replies' OR 'View reply' button # 496 ...
# 497 . Attempting to click 'View [x] replies' OR 'View reply' button # 497 ...
# 498 . Attempting to click 'View [x] replies' OR 'View reply' button # 498 ...
# 499 . Attempting to click 'View [x] replies' OR 'View reply' button # 499 ...
# 500 . Attempting to click 'View [x] replies' OR 'View reply' button # 500 ...
# 501 . Attempting to click 'View [x] replies' OR 'View reply' button # 501 ...
# 502 . Attempting to click 'View [x] replies' OR 'View reply' button # 502 ...
# 503 . Attempting to click 'View [x] replies' OR 'View reply' button # 503 ...
# 504 . Attempting to click 'View [x] replies' OR 'View reply' button # 504 ...
# 505 . Attempting to click 'View [x] replies' OR 'View reply' button # 505 ...
# 506 . Attempting to click 'View [x] replies' OR 'View reply' button # 506 ...
# 507 . Attempting to click 'View [x] replies' OR 'View reply' button # 507 ...
# 508 . Attempting to click 'View [x] replies' OR 'View reply' button # 508 ...
# 509 . Attempting to click 'View [x] replies' OR 'View reply' button # 509 ...
# 510 . Attempting to click 'View [x] replies' OR 'View reply' button # 510 ...
# 511 . Attempting to click 'View [x] replies' OR 'View reply' button # 511 ...
# 512 . Attempting to click 'View [x] replies' OR 'View reply' button # 512 ...
# 513 . Attempting to click 'View [x] replies' OR 'View reply' button # 513 ...
# 514 . Attempting to click 'View [x] replies' OR 'View reply' button # 514 ...
# 515 . Attempting to click 'View [x] replies' OR 'View reply' button # 515 ...
# 516 . Attempting to click 'View [x] replies' OR 'View reply' button # 516 ...
# 517 . Attempting to click 'View [x] replies' OR 'View reply' button # 517 ...
# 518 . Attempting to click 'View [x] replies' OR 'View reply' button # 518 ...
# 519 . Attempting to click 'View [x] replies' OR 'View reply' button # 519 ...
# 520 . Attempting to click 'View [x] replies' OR 'View reply' button # 520 ...
# 521 . Attempting to click 'View [x] replies' OR 'View reply' button # 521 ...
# 522 . Attempting to click 'View [x] replies' OR 'View reply' button # 522 ...
# 523 . Attempting to click 'View [x] replies' OR 'View reply' button # 523 ...
# 524 . Attempting to click 'View [x] replies' OR 'View reply' button # 524 ...
# 525 . Attempting to click 'View [x] replies' OR 'View reply' button # 525 ...
# 526 . Attempting to click 'View [x] replies' OR 'View reply' button # 526 ...
# 527 . Attempting to click 'View [x] replies' OR 'View reply' button # 527 ...
# 528 . Attempting to click 'View [x] replies' OR 'View reply' button # 528 ...
# 529 . Attempting to click 'View [x] replies' OR 'View reply' button # 529 ...
# 530 . Attempting to click 'View [x] replies' OR 'View reply' button # 530 ...
# 531 . Attempting to click 'View [x] replies' OR 'View reply' button # 531 ...
# 532 . Attempting to click 'View [x] replies' OR 'View reply' button # 532 ...
# 533 . Attempting to click 'View [x] replies' OR 'View reply' button # 533 ...
# 534 . Attempting to click 'View [x] replies' OR 'View reply' button # 534 ...
# 535 . Attempting to click 'View [x] replies' OR 'View reply' button # 535 ...
# 536 . Attempting to click 'View [x] replies' OR 'View reply' button # 536 ...
# 537 . Attempting to click 'View [x] replies' OR 'View reply' button # 537 ...
# 538 . Attempting to click 'View [x] replies' OR 'View reply' button # 538 ...
# 539 . Attempting to click 'View [x] replies' OR 'View reply' button # 539 ...
# 540 . Attempting to click 'View [x] replies' OR 'View reply' button # 540 ...
# 541 . Attempting to click 'View [x] replies' OR 'View reply' button # 541 ...
# 542 . Attempting to click 'View [x] replies' OR 'View reply' button # 542 ...
# 543 . Attempting to click 'View [x] replies' OR 'View reply' button # 543 ...
# 544 . Attempting to click 'View [x] replies' OR 'View reply' button # 544 ...
# 545 . Attempting to click 'View [x] replies' OR 'View reply' button # 545 ...
# 546 . Attempting to click 'View [x] replies' OR 'View reply' button # 546 ...
# 547 . Attempting to click 'View [x] replies' OR 'View reply' button # 547 ...
# 548 . Attempting to click 'View [x] replies' OR 'View reply' button # 548 ...
# 549 . Attempting to click 'View [x] replies' OR 'View reply' button # 549 ...
# 550 . Attempting to click 'View [x] replies' OR 'View reply' button # 550 ...
# 551 . Attempting to click 'View [x] replies' OR 'View reply' button # 551 ...
# 552 . Attempting to click 'View [x] replies' OR 'View reply' button # 552 ...
# 553 . Attempting to click 'View [x] replies' OR 'View reply' button # 553 ...
# 554 . Attempting to click 'View [x] replies' OR 'View reply' button # 554 ...
# 555 . Attempting to click 'View [x] replies' OR 'View reply' button # 555 ...
# 556 . Attempting to click 'View [x] replies' OR 'View reply' button # 556 ...
# 557 . Attempting to click 'View [x] replies' OR 'View reply' button # 557 ...
# 558 . Attempting to click 'View [x] replies' OR 'View reply' button # 558 ...
# 559 . Attempting to click 'View [x] replies' OR 'View reply' button # 559 ...
# 560 . Attempting to click 'View [x] replies' OR 'View reply' button # 560 ...
# 561 . Attempting to click 'View [x] replies' OR 'View reply' button # 561 ...
# 562 . Attempting to click 'View [x] replies' OR 'View reply' button # 562 ...
# 563 . Attempting to click 'View [x] replies' OR 'View reply' button # 563 ...
# 564 . Attempting to click 'View [x] replies' OR 'View reply' button # 564 ...
# 565 . Attempting to click 'View [x] replies' OR 'View reply' button # 565 ...
# 566 . Attempting to click 'View [x] replies' OR 'View reply' button # 566 ...
# 567 . Attempting to click 'View [x] replies' OR 'View reply' button # 567 ...
# 568 . Attempting to click 'View [x] replies' OR 'View reply' button # 568 ...
# 569 . Attempting to click 'View [x] replies' OR 'View reply' button # 569 ...
# 570 . Attempting to click 'View [x] replies' OR 'View reply' button # 570 ...
# 571 . Attempting to click 'View [x] replies' OR 'View reply' button # 571 ...
# 572 . Attempting to click 'View [x] replies' OR 'View reply' button # 572 ...
# 573 . Attempting to click 'View [x] replies' OR 'View reply' button # 573 ...
# 574 . Attempting to click 'View [x] replies' OR 'View reply' button # 574 ...
# 575 . Attempting to click 'View [x] replies' OR 'View reply' button # 575 ...

# %%
# Click on "Show more replies"
# All cases: "Show more replies" (regardless if there is only 1 more reply to show)
click_ALL_ShowMoreReplies()
# Out:
# ----- 0 'Show more replies' elements found -----
#
# No 'Show more replies' buttons detected

# %%
# Get video title
video_title = get_video_title()
# Out:
# Getting video title...
# Video title: We drove these electric cars until they DIED!

# %%
# Get all usernames
usernames = get_ALL_usernames()
# Out:
# Attempting to get ALL usernames...
# Attempting to get normal usernames...
# 	Length of username_elements = 6998
# 	Length of usernames = 6998
# Counting empty usernames in normal_usernames...
# 	Number of empty usernames in normal_usernames = 10
# Attempting to get styled usernames...
# 	Length of styled_username_elements = 0
# 	Length of styled_usernames = 0
# 	Number of found styled usernames = number of empty usernames? -- False
# 		Leaving empty usernames as is

# %%
# Get all timestamps ("[time] ago")
timestamps = get_ALL_timestamps()
# Out:
# Attempting to get ALL timestamps...
# Length of timestamp_elements = 6998
# Length of timestamps = 6998

# %%
# Parse all timestamps:
parsed_timestamps = get_ALL_parsed_timestamps(timestamps)
# Out:
# Attempting to get ALL parsed timestamp data...
# Length of timestamp_numbers = 6998
# Length of timestamp_units = 6998
# Length of timestamp_edited = 6998

# %%
# Get all comments
comments = get_ALL_comments()
# Out:
# Attempting to get ALL comments...
# Length of comment_elements = 6998
# Length of comments = 6998

# %%
# Get all upvotes
upvotes = get_ALL_upvotes()
# Out:
# Attempting to get ALL upvotes...
# Length of upvote_elements = 6998
# Length of upvotes = 6998

# %%
if (len(usernames) == 
    len(timestamps) == 
    len(parsed_timestamps[0]) == 
    len(parsed_timestamps[1]) ==
    len(parsed_timestamps[2]) ==
    len(comments)):
    print("Lengths of usernames, timestamps, 3 fields in parsed_timestamps, and comments are equal? -- True\n")
else:
    print("Lengths of usernames, timestamps, 3 fields in parsed_timestamps, and comments are equal? -- False")
    print("Please re-run script.\n")
# Out:
# Lengths of usernames, timestamps, 3 fields in parsed_timestamps, and comments are equal? -- True

# %%
# Make custom comment IDs "My Comment IDs"
MyCommentIDs = make_MyCommentIDs(len(comments))

# Make list of sources (all comments should have the same source, "YouTube")
sources = make_sources(len(comments))

# Make list of video titles (all comments should have the same video title)
video_titles = make_video_titles(len(comments), video_title)

# Make list of URLs (all comments should have the same video URL)
URLs = make_URLs(len(comments))

# %%
print("Captured comments: ", len(comments), "/", num_comments)
# Out:
# Captured comments:  6998 / 13,837

# %%
# Make custom comment IDs "My Comment IDs"
MyCommentIDs = make_MyCommentIDs(len(comments))

# Make list of video titles (all comments should have the same video title)
video_titles = make_video_titles(len(comments), video_title)

# Make list of URLs (all comments should have the same video URL)
URLs = make_URLs(len(comments))

# %%
# Create Pandas DataFrame

# New column names
data = {"my_comment_id": MyCommentIDs,
        "source": sources,
        "video_title": video_titles,
        "username": usernames,
        "comment": comments,
        "timestamp": timestamps,
        "timestamp_number": parsed_timestamps[0],
        "timestamp_unit": parsed_timestamps[1],
        "edited": parsed_timestamps[2],
        "upvotes": upvotes,
        "url": URLs}

df = pd.DataFrame(data)

# %%
df
# Out:
#                my_comment_id   source  \
# 0        YT_ZH7V2tU3iFc_Com1  YouTube
# 1        YT_ZH7V2tU3iFc_Com2  YouTube
# 2        YT_ZH7V2tU3iFc_Com3  YouTube
# 3        YT_ZH7V2tU3iFc_Com4  YouTube
# 4        YT_ZH7V2tU3iFc_Com5  YouTube
# ...                      ...      ...
# 6993  YT_ZH7V2tU3iFc_Com6994  YouTube
# 6994  YT_ZH7V2tU3iFc_Com6995  YouTube
# 6995  YT_ZH7V2tU3iFc_Com6996  YouTube
# 6996  YT_ZH7V2tU3iFc_Com6997  YouTube
# 6997  YT_ZH7V2tU3iFc_Com6998  YouTube
#
#                                         video_title     username  \
# 0     We drove these electric cars until they DIED!   Billie Boe
# 1     We drove these electric cars until they DIED!       Felipe
# 2     We drove these electric cars until they DIED!  Sambenmoser
# 3     We drove these electric cars until they DIED!       R-Type
# 4     We drove these electric cars until they DIED!          SRA
# ...                                             ...          ...
# 6993  We drove these electric cars until they DIED!      lecisko
# 6994  We drove these electric cars until they DIED!   medler2110
# 6995  We drove these electric cars until they DIED!      lecisko
# 6996  We drove these electric cars until they DIED!     AutoChap
# 6997  We drove these electric cars until they DIED!       Fleyua
#
#                                                 comment            timestamp  \
# 0     For those who uses metric and want to know how...  1 year ago (edited)
# 1                 Kia offers great value for the money.           1 year ago
# 2                                  Kia wins this for me           1 year ago
# 3                         Thanks man, much appreciated!           1 year ago
# 4                                                 JAG 💕           1 year ago
# ...                                                 ...                  ...
# 6993   @medler2110  go for it. But other then the ra...           1 year ago
# 6994  Maybe they are, but with £15k I could do plent...           1 year ago
# 6995   @medler2110  Absolutely fine. Buy any EV you ...           1 year ago
# 6996                                  Tesla is the best           1 year ago
# 6997                                       Fanboy above           1 year ago
#
#      timestamp_number timestamp_unit edited upvotes  \
# 0                   1           year    Yes     31K
# 1                   1           year     No    1.5K
# 2                   1           year     No     849
# 3                   1           year     No     170
# 4                   1           year     No      73
# ...               ...            ...    ...     ...
# 6993                1           year     No       0
# 6994                1           year     No       0
# 6995                1           year     No       0
# 6996                1           year     No       4
# 6997                1           year     No       0
#
#                                               url
# 0     https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 1     https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 2     https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 3     https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 4     https://www.youtube.com/watch?v=ZH7V2tU3iFc
# ...                                           ...
# 6993  https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 6994  https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 6995  https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 6996  https://www.youtube.com/watch?v=ZH7V2tU3iFc
# 6997  https://www.youtube.com/watch?v=ZH7V2tU3iFc
#
# [6998 rows x 11 columns]

# %%
print(df.iloc[0]["comment"])
# Out:
# For those who uses metric and want to know how far these cars went:
#
# Mercedes : 194 miles = 312km
# Audi : 206 miles = 331km

# %%
# Export Pandas DataFrame object to a .csv file using encoding='utf-8-sig'
df.to_csv((path_to_folder + filename), index = None, header=True, encoding='utf-8-sig')

# # Export Pandas DataFrame object to a .csv file using encoding='utf-8'
df.to_csv((path_to_folder + "utf-8_" + filename), index = None, header=True, encoding='utf-8')

# %%
# Close Chrome Driver
driver.close()
